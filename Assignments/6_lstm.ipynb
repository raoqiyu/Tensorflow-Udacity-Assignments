# %% [markdown]
# Deep Learning
# =============
#
# Assignment 6
# ------------
#
# After training a skip-gram model in `5_word2vec.ipynb`, the goal of this notebook is to train a LSTM character model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
from __future__ import print_function
import os
import numpy as np
import random
import string
import tensorflow as tf
import zipfile
from six.moves import range
from six.moves.urllib.request import urlretrieve

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %%
def read_data(filename):
  f = zipfile.ZipFile(filename)
  for name in f.namelist():
    return tf.compat.as_str(f.read(name))
  f.close()
  
text = read_data(filename)
print('Data size %d' % len(text))
# Out:
# Data size 100000000

# %% [markdown]
# Create a small validation set.

# %%
valid_size = 1000
valid_text = text[:valid_size]
train_text = text[valid_size:]
train_size = len(train_text)
print(train_size, train_text[:64])
print(valid_size, valid_text[:64])
# Out:
# 99999000 ons anarchists advocate social relations based upon voluntary as
# 1000  anarchism originated as a term of abuse first used against earl

# %% [markdown]
# Utility functions to map characters to vocabulary IDs and back.

# %%
vocabulary_size = len(string.ascii_lowercase) + 1 # [a-z] + ' '
first_letter = ord(string.ascii_lowercase[0])

def char2id(char):
  if char in string.ascii_lowercase:
    return ord(char) - first_letter + 1
  elif char == ' ':
    return 0
  else:
    print('Unexpected character: %s' % char)
    return 0
  
def id2char(dictid):
  if dictid > 0:
    return chr(dictid + first_letter - 1)
  else:
    return ' '

print(char2id('a'), char2id('z'), char2id(' '), char2id('ï'))
print(id2char(1), id2char(26), id2char(0))
# Out:
# Unexpected character: ï
# 1 26 0 0
# a z

# %% [markdown]
# Function to generate a training batch for the LSTM model.

# %%
batch_size=64
num_unrollings=10

class BatchGenerator(object):
  def __init__(self, text, batch_size, num_unrollings):
    self._text = text
    self._text_size = len(text)
    self._batch_size = batch_size
    self._num_unrollings = num_unrollings
    segment = self._text_size // batch_size
    self._cursor = [ offset * segment for offset in range(batch_size)]
    self._last_batch = self._next_batch()
  
  def _next_batch(self):
    """Generate a single batch from the current cursor position in the data."""
    batch = np.zeros(shape=(self._batch_size, vocabulary_size), dtype=np.float)
    for b in range(self._batch_size):
      batch[b, char2id(self._text[self._cursor[b]])] = 1.0
      self._cursor[b] = (self._cursor[b] + 1) % self._text_size
    return batch
  
  def next(self):
    """Generate the next array of batches from the data. The array consists of
    the last batch of the previous array, followed by num_unrollings new ones.
    """
    batches = [self._last_batch]
    for step in range(self._num_unrollings):
      #print(characters(batches[-1]))
      batches.append(self._next_batch())
    self._last_batch = batches[-1]
    return batches

def characters(probabilities):
  """Turn a 1-hot encoding or a probability distribution over the possible
  characters back into its (most likely) character representation."""
  return [id2char(c) for c in np.argmax(probabilities, 1)]

def batches2string(batches):
  """Convert a sequence of batches back into their (most likely) string
  representation."""
  s = [''] * batches[0].shape[0]
  for b in batches:
    s = [''.join(x) for x in zip(s, characters(b))]
  return s

train_batches = BatchGenerator(train_text, batch_size, num_unrollings)
valid_batches = BatchGenerator(valid_text, 1, 1)

print(batches2string(train_batches.next()))
print(batches2string(train_batches.next()))
print(batches2string(valid_batches.next()))
print(batches2string(valid_batches.next()))
# Out:
# ['ons anarchi', 'when milita', 'lleria arch', ' abbeys and', 'married urr', 'hel and ric', 'y and litur', 'ay opened f', 'tion from t', 'migration t', 'new york ot', 'he boeing s', 'e listed wi', 'eber has pr', 'o be made t', 'yer who rec', 'ore signifi', 'a fierce cr', ' two six ei', 'aristotle s', 'ity can be ', ' and intrac', 'tion of the', 'dy to pass ', 'f certain d', 'at it will ', 'e convince ', 'ent told hi', 'ampaign and', 'rver side s', 'ious texts ', 'o capitaliz', 'a duplicate', 'gh ann es d', 'ine january', 'ross zero t', 'cal theorie', 'ast instanc', ' dimensiona', 'most holy m', 't s support', 'u is still ', 'e oscillati', 'o eight sub', 'of italy la', 's the tower', 'klahoma pre', 'erprise lin', 'ws becomes ', 'et in a naz', 'the fabian ', 'etchy to re', ' sharman ne', 'ised empero', 'ting in pol', 'd neo latin', 'th risky ri', 'encyclopedi', 'fense the a', 'duating fro', 'treet grid ', 'ations more', 'appeal of d', 'si have mad']
# ['ists advoca', 'ary governm', 'hes nationa', 'd monasteri', 'raca prince', 'chard baer ', 'rgical lang', 'for passeng', 'the nationa', 'took place ', 'ther well k', 'seven six s', 'ith a gloss', 'robably bee', 'to recogniz', 'ceived the ', 'icant than ', 'ritic of th', 'ight in sig', 's uncaused ', ' lost as in', 'cellular ic', 'e size of t', ' him a stic', 'drugs confu', ' take to co', ' the priest', 'im to name ', 'd barred at', 'standard fo', ' such as es', 'ze on the g', 'e of the or', 'd hiver one', 'y eight mar', 'the lead ch', 'es classica', 'ce the non ', 'al analysis', 'mormons bel', 't or at lea', ' disagreed ', 'ing system ', 'btypes base', 'anguages th', 'r commissio', 'ess one nin', 'nux suse li', ' the first ', 'zi concentr', ' society ne', 'elatively s', 'etworks sha', 'or hirohito', 'litical ini', 'n most of t', 'iskerdoo ri', 'ic overview', 'air compone', 'om acnm acc', ' centerline', 'e than any ', 'devotional ', 'de such dev']
# [' a']
# ['an']

# %%
def logprob(predictions, labels):
  """Log-probability of the true labels in a predicted batch."""
  predictions[predictions < 1e-10] = 1e-10
  return np.sum(np.multiply(labels, -np.log(predictions))) / labels.shape[0]

def sample_distribution(distribution):
  """Sample one element from a distribution assumed to be an array of normalized
  probabilities.
  """
  r = random.uniform(0, 1)
  s = 0
  for i in range(len(distribution)):
    s += distribution[i]
    if s >= r:
      return i
  return len(distribution) - 1

def sample(prediction):
  """Turn a (column) prediction into 1-hot encoded samples."""
  p = np.zeros(shape=[1, vocabulary_size], dtype=np.float)
  p[0, sample_distribution(prediction[0])] = 1.0
  return p

def random_distribution():
  """Generate a random column of probabilities."""
  b = np.random.uniform(0.0, 1.0, size=[1, vocabulary_size])
  return b/np.sum(b, 1)[:,None]

# %% [markdown]
# Simple LSTM Model.

# %%
num_nodes = 64

graph = tf.Graph()
with graph.as_default():
  
  # Parameters:
  # Input gate: input, previous output, and bias.
  ix = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
  im = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  ib = tf.Variable(tf.zeros([1, num_nodes]))
  # Forget gate: input, previous output, and bias.
  fx = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
  fm = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  fb = tf.Variable(tf.zeros([1, num_nodes]))
  # Memory cell: input, state and bias.                             
  cx = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
  cm = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  cb = tf.Variable(tf.zeros([1, num_nodes]))
  # Output gate: input, previous output, and bias.
  ox = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
  om = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  ob = tf.Variable(tf.zeros([1, num_nodes]))
  # Variables saving state across unrollings.
  saved_output = tf.Variable(tf.zeros([batch_size, num_nodes]), trainable=False)
  saved_state = tf.Variable(tf.zeros([batch_size, num_nodes]), trainable=False)
  # Classifier weights and biases.
  w = tf.Variable(tf.truncated_normal([num_nodes, vocabulary_size], -0.1, 0.1))
  b = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Definition of the cell computation.
  def lstm_cell(i, o, state):
    """Create a LSTM cell. See e.g.: http://arxiv.org/pdf/1402.1128v1.pdf
    Note that in this formulation, we omit the various connections between the
    previous state and the gates."""
    input_gate = tf.sigmoid(tf.matmul(i, ix) + tf.matmul(o, im) + ib)
    forget_gate = tf.sigmoid(tf.matmul(i, fx) + tf.matmul(o, fm) + fb)
    update = tf.matmul(i, cx) + tf.matmul(o, cm) + cb
    state = forget_gate * state + input_gate * tf.tanh(update)
    output_gate = tf.sigmoid(tf.matmul(i, ox) + tf.matmul(o, om) + ob)
    return output_gate * tf.tanh(state), state

  # Input data.
  train_data = list()
  for _ in range(num_unrollings + 1):
    train_data.append(
      tf.placeholder(tf.float32, shape=[batch_size,vocabulary_size]))
  train_inputs = train_data[:num_unrollings]
  train_labels = train_data[1:]  # labels are inputs shifted by one time step.

  # Unrolled LSTM loop.
  outputs = list()
  output = saved_output
  state = saved_state
  for i in train_inputs:
    output, state = lstm_cell(i, output, state)
    outputs.append(output)

  # State saving across unrollings.
  with tf.control_dependencies([saved_output.assign(output),
                                saved_state.assign(state)]):
    # Classifier.
    logits = tf.nn.xw_plus_b(tf.concat(0, outputs), w, b)
    loss = tf.reduce_mean(
      tf.nn.softmax_cross_entropy_with_logits(
        logits, tf.concat(0, train_labels)))

  # Optimizer.
  global_step = tf.Variable(0)
  learning_rate = tf.train.exponential_decay(
    10.0, global_step, 5000, 0.1, staircase=True)
  optimizer = tf.train.GradientDescentOptimizer(learning_rate)
  gradients, v = zip(*optimizer.compute_gradients(loss))
  gradients, _ = tf.clip_by_global_norm(gradients, 1.25)
  optimizer = optimizer.apply_gradients(
    zip(gradients, v), global_step=global_step)

  # Predictions.
  train_prediction = tf.nn.softmax(logits)
  
  # Sampling and validation eval: batch 1, no unrolling.
  sample_input = tf.placeholder(tf.float32, shape=[1, vocabulary_size])
  saved_sample_output = tf.Variable(tf.zeros([1, num_nodes]))
  saved_sample_state = tf.Variable(tf.zeros([1, num_nodes]))
  reset_sample_state = tf.group(
    saved_sample_output.assign(tf.zeros([1, num_nodes])),
    saved_sample_state.assign(tf.zeros([1, num_nodes])))
  sample_output, sample_state = lstm_cell(
    sample_input, saved_sample_output, saved_sample_state)
  with tf.control_dependencies([saved_sample_output.assign(sample_output),
                                saved_sample_state.assign(sample_state)]):
    sample_prediction = tf.nn.softmax(tf.nn.xw_plus_b(sample_output, w, b))

# %%
num_steps = 7001
summary_frequency = 100

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  mean_loss = 0
  for step in range(num_steps):
    batches = train_batches.next()
    feed_dict = dict()
    for i in range(num_unrollings + 1):
      feed_dict[train_data[i]] = batches[i]
    _, l, predictions, lr = session.run(
      [optimizer, loss, train_prediction, learning_rate], feed_dict=feed_dict)
    mean_loss += l
    if step % summary_frequency == 0:
      if step > 0:
        mean_loss = mean_loss / summary_frequency
      # The mean loss is an estimate of the loss over the last few batches.
      print(
        'Average loss at step %d: %f learning rate: %f' % (step, mean_loss, lr))
      mean_loss = 0
      labels = np.concatenate(list(batches)[1:])
      print('Minibatch perplexity: %.2f' % float(
        np.exp(logprob(predictions, labels))))
      if step % (summary_frequency * 10) == 0:
        # Generate some samples.
        print('=' * 80)
        for _ in range(5):
          feed = sample(random_distribution())
          sentence = characters(feed)[0]
          reset_sample_state.run()
          for _ in range(79):
            prediction = sample_prediction.eval({sample_input: feed})
            feed = sample(prediction)
            sentence += characters(feed)[0]
          print(sentence)
        print('=' * 80)
      # Measure validation set perplexity.
      reset_sample_state.run()
      valid_logprob = 0
      for _ in range(valid_size):
        b = valid_batches.next()
        predictions = sample_prediction.eval({sample_input: b[0]})
        valid_logprob = valid_logprob + logprob(predictions, b[1])
      print('Validation set perplexity: %.2f' % float(np.exp(
        valid_logprob / valid_size)))
# Out:
# Initialized
# Average loss at step 0: 3.293185 learning rate: 10.000000
# Minibatch perplexity: 26.93
# ================================================================================
# sftls  ictmeaiwl fa  k bpfu yhosd  n oxeakxhtdelyavelcoencs  bbjnicm feqowwffx s
# aqdzjnowltdrtjfhr fnielrqodogcvh tpaecs  nellddo m  m crsm bli h eozyb exprlcrfu
# cu rieeau iirewnefnnsum steejnnznhdstnuledltiurbswpacqcxgtzmhvh flmacxvn  zoboc
# oehgebe e imtmrmfinnth mdsaciiink b ggebmip  wvdt esfsltlcsjygsmjigxt w khejkr p
# oem gdhom raizgidt lgfaht mqhbw vtuca q gf fwuhoonxgbbah lslsxg tca ulmqcs unjed
# ================================================================================
# Validation set perplexity: 20.14
# Average loss at step 100: 2.600774 learning rate: 10.000000
# Minibatch perplexity: 11.00
# Validation set perplexity: 10.37
# Average loss at step 200: 2.261845 learning rate: 10.000000
# Minibatch perplexity: 8.58
# Validation set perplexity: 8.65
# Average loss at step 300: 2.101670 learning rate: 10.000000
# Minibatch perplexity: 7.39
# Validation set perplexity: 8.01
# Average loss at step 400: 2.000382 learning rate: 10.000000
# Minibatch perplexity: 7.55
# Validation set perplexity: 7.71
# Average loss at step 500: 1.937701 learning rate: 10.000000
# Minibatch perplexity: 6.52
# Validation set perplexity: 7.06
# Average loss at step 600: 1.911064 learning rate: 10.000000
# Minibatch perplexity: 6.28
# Validation set perplexity: 6.92
# Average loss at step 700: 1.863149 learning rate: 10.000000
# Minibatch perplexity: 6.51
# Validation set perplexity: 6.45
# Average loss at step 800: 1.820008 learning rate: 10.000000
# Minibatch perplexity: 5.95
# Validation set perplexity: 6.24
# Average loss at step 900: 1.830488 learning rate: 10.000000
# Minibatch perplexity: 7.07
# Validation set perplexity: 6.22
# Average loss at step 1000: 1.827159 learning rate: 10.000000
# Minibatch perplexity: 5.54
# ================================================================================
# rmited the ereccessery beake the tible s rose zero zeroly xalle for the center p
# s one oven in mensully in stabil as i storic confrectionisg orpbe of of dold and
# nch dicle of the beading the lablly ming giffersan edeniqy the abeer civraning c
# graor endiallys mayanathre freligles nicand the to bother and refivile pirgual c
# graal he there versopol undera crairy late he sarfinial ruckiapaye infecone unde
# ================================================================================
# Validation set perplexity: 5.98
# Average loss at step 1100: 1.779402 learning rate: 10.000000
# Minibatch perplexity: 5.72
# Validation set perplexity: 5.82
# Average loss at step 1200: 1.755258 learning rate: 10.000000
# Minibatch perplexity: 5.02
# Validation set perplexity: 5.55
# Average loss at step 1300: 1.733456 learning rate: 10.000000
# Minibatch perplexity: 5.68
# Validation set perplexity: 5.48
# Average loss at step 1400: 1.750009 learning rate: 10.000000
# Minibatch perplexity: 6.02
# Validation set perplexity: 5.40
# Average loss at step 1500: 1.739157 learning rate: 10.000000
# Minibatch perplexity: 4.94
# Validation set perplexity: 5.27
# Average loss at step 1600: 1.745030 learning rate: 10.000000
# Minibatch perplexity: 5.55
# Validation set perplexity: 5.30
# Average loss at step 1700: 1.711965 learning rate: 10.000000
# Minibatch perplexity: 5.60
# Validation set perplexity: 5.22
# Average loss at step 1800: 1.676805 learning rate: 10.000000
# Minibatch perplexity: 5.53
# Validation set perplexity: 5.09
# Average loss at step 1900: 1.649035 learning rate: 10.000000
# Minibatch perplexity: 4.99
# Validation set perplexity: 5.17
# Average loss at step 2000: 1.697861 learning rate: 10.000000
# Minibatch perplexity: 5.70
# ================================================================================
# s actusing in one nine four only p court grissivies and non it joukenies is nica
# finingy at the campt patesual in notlinates cope as of that foo standed in the o
# f soine ormble linnually for revelture the patlendial on commbine was prossimudi
# but phed s suquase donity in nym cretism the the apteatur waicas positication so
# jans stanking ray the payers and haws be and bowinisquing the kut two zero zero
# ================================================================================
# Validation set perplexity: 5.08
# Average loss at step 2100: 1.689476 learning rate: 10.000000
# Minibatch perplexity: 5.16
# Validation set perplexity: 4.78
# Average loss at step 2200: 1.686244 learning rate: 10.000000
# Minibatch perplexity: 6.54
# Validation set perplexity: 4.87
# Average loss at step 2300: 1.644652 learning rate: 10.000000
# Minibatch perplexity: 4.97
# Validation set perplexity: 4.70
# Average loss at step 2400: 1.663461 learning rate: 10.000000
# Minibatch perplexity: 5.28
# Validation set perplexity: 4.75
# Average loss at step 2500: 1.682486 learning rate: 10.000000
# Minibatch perplexity: 5.41
# Validation set perplexity: 4.57
# Average loss at step 2600: 1.657295 learning rate: 10.000000
# Minibatch perplexity: 5.73
# Validation set perplexity: 4.60
# Average loss at step 2700: 1.657585 learning rate: 10.000000
# Minibatch perplexity: 4.56
# Validation set perplexity: 4.63
# Average loss at step 2800: 1.652154 learning rate: 10.000000
# Minibatch perplexity: 5.51
# Validation set perplexity: 4.56
# Average loss at step 2900: 1.647631 learning rate: 10.000000
# Minibatch perplexity: 5.51
# Validation set perplexity: 4.60
# Average loss at step 3000: 1.649778 learning rate: 10.000000
# Minibatch perplexity: 4.93
# ================================================================================
# on meayiti ale spain astread after heich the beamshator is axstard ricel be plan
# her with the direlt in subrich jahear was gorapicoal over eapo in meeul from ass
# lanses a swott one eight six became he pow one nine subbations and pas of and au
# s scautist deplasing sipenned mibicanide was non the jackards ald films and scot
# land letten of as of gikand to and compotical oles socorrationity many promizes
# ================================================================================
# Validation set perplexity: 4.63
# Average loss at step 3100: 1.627873 learning rate: 10.000000
# Minibatch perplexity: 5.69
# Validation set perplexity: 4.61
# Average loss at step 3200: 1.648894 learning rate: 10.000000
# Minibatch perplexity: 5.74
# Validation set perplexity: 4.55
# Average loss at step 3300: 1.640624 learning rate: 10.000000
# Minibatch perplexity: 5.02
# Validation set perplexity: 4.57
# Average loss at step 3400: 1.671775 learning rate: 10.000000
# Minibatch perplexity: 5.48
# Validation set perplexity: 4.53
# Average loss at step 3500: 1.660620 learning rate: 10.000000
# Minibatch perplexity: 5.51
# Validation set perplexity: 4.61
# Average loss at step 3600: 1.666859 learning rate: 10.000000
# Minibatch perplexity: 4.40
# Validation set perplexity: 4.45
# Average loss at step 3700: 1.643134 learning rate: 10.000000
# Minibatch perplexity: 5.07
# Validation set perplexity: 4.46
# Average loss at step 3800: 1.644945 learning rate: 10.000000
# Minibatch perplexity: 5.46
# Validation set perplexity: 4.55
# Average loss at step 3900: 1.637304 learning rate: 10.000000
# Minibatch perplexity: 5.21
# Validation set perplexity: 4.42
# Average loss at step 4000: 1.653593 learning rate: 10.000000
# Minibatch perplexity: 4.74
# ================================================================================
# ces whese deplefes homous thereber appesses was be revermey incesporr byoase or
# poit i one three zero zero five joungrovoyb more n disels abbytaguimation defini
# war only deodds entory tharmi a one eing eight bense the americas the fiest impe
# jessecred incussite list spart of ote the indep over the groups one nine five on
# x about more s relative drown the kame in dup the protocket belaid brough from t
# ================================================================================
# Validation set perplexity: 4.57
# Average loss at step 4100: 1.630841 learning rate: 10.000000
# Minibatch perplexity: 5.39
# Validation set perplexity: 4.60
# Average loss at step 4200: 1.634482 learning rate: 10.000000
# Minibatch perplexity: 5.24
# Validation set perplexity: 4.41
# Average loss at step 4300: 1.615084 learning rate: 10.000000
# Minibatch perplexity: 5.02
# Validation set perplexity: 4.49
# Average loss at step 4400: 1.608967 learning rate: 10.000000
# Minibatch perplexity: 4.71
# Validation set perplexity: 4.35
# Average loss at step 4500: 1.614347 learning rate: 10.000000
# Minibatch perplexity: 5.23
# Validation set perplexity: 4.48
# Average loss at step 4600: 1.615864 learning rate: 10.000000
# Minibatch perplexity: 5.00
# Validation set perplexity: 4.43
# Average loss at step 4700: 1.630093 learning rate: 10.000000
# Minibatch perplexity: 5.43
# Validation set perplexity: 4.37
# Average loss at step 4800: 1.631026 learning rate: 10.000000
# Minibatch perplexity: 4.42
# Validation set perplexity: 4.38
# Average loss at step 4900: 1.634451 learning rate: 10.000000
# Minibatch perplexity: 5.05
# Validation set perplexity: 4.49
# Average loss at step 5000: 1.607503 learning rate: 1.000000
# Minibatch perplexity: 4.46
# ================================================================================
# en the it with the one s some for that bots agoven a saict as a five reach sire
# phizations cands in obdanies ang tride is a commonly freach zero but reath yivet
# genar assecally subsette of twent by to pititude from flour by havy for a zero l
# uction the model are the ranesui hin grade yousisimy as lefsel of some word kn d
# volucts and hy antridreming by the two poguens and rome that letten bay the capo
# ================================================================================
# Validation set perplexity: 4.50
# Average loss at step 5100: 1.601317 learning rate: 1.000000
# Minibatch perplexity: 4.87
# Validation set perplexity: 4.33
# Average loss at step 5200: 1.588666 learning rate: 1.000000
# Minibatch perplexity: 4.52
# Validation set perplexity: 4.27
# Average loss at step 5300: 1.582270 learning rate: 1.000000
# Minibatch perplexity: 4.69
# Validation set perplexity: 4.26
# Average loss at step 5400: 1.583716 learning rate: 1.000000
# Minibatch perplexity: 4.98
# Validation set perplexity: 4.25
# Average loss at step 5500: 1.567182 learning rate: 1.000000
# Minibatch perplexity: 4.84
# Validation set perplexity: 4.21
# Average loss at step 5600: 1.577838 learning rate: 1.000000
# Minibatch perplexity: 4.83
# Validation set perplexity: 4.21
# Average loss at step 5700: 1.565924 learning rate: 1.000000
# Minibatch perplexity: 4.51
# Validation set perplexity: 4.23
# Average loss at step 5800: 1.582963 learning rate: 1.000000
# Minibatch perplexity: 4.87
# Validation set perplexity: 4.21
# Average loss at step 5900: 1.569461 learning rate: 1.000000
# Minibatch perplexity: 5.08
# Validation set perplexity: 4.18
# Average loss at step 6000: 1.549456 learning rate: 1.000000
# Minibatch perplexity: 5.26
# ================================================================================
# el is a frinua esback they are n clame sumber the ston henruasive slon former fo
# b a as g two two zero four eight one eight seven nine one nine three posed spara
# zely during now they this cultatou unitiens was and exc asplotin two zero zero z
# jenge incupe denotian eleck awaries suplamboley usologed wards it is when a name
# jot main stranged to these famerian size non then firing provisistred grael one
# ================================================================================
# Validation set perplexity: 4.18
# Average loss at step 6100: 1.568445 learning rate: 1.000000
# Minibatch perplexity: 5.03
# Validation set perplexity: 4.18
# Average loss at step 6200: 1.537315 learning rate: 1.000000
# Minibatch perplexity: 4.88
# Validation set perplexity: 4.16
# Average loss at step 6300: 1.548152 learning rate: 1.000000
# Minibatch perplexity: 5.09
# Validation set perplexity: 4.16
# Average loss at step 6400: 1.539641 learning rate: 1.000000
# Minibatch perplexity: 4.38
# Validation set perplexity: 4.18
# Average loss at step 6500: 1.561242 learning rate: 1.000000
# Minibatch perplexity: 4.63
# Validation set perplexity: 4.16
# Average loss at step 6600: 1.595935 learning rate: 1.000000
# Minibatch perplexity: 4.87
# Validation set perplexity: 4.15
# Average loss at step 6700: 1.582635 learning rate: 1.000000
# Minibatch perplexity: 4.98
# Validation set perplexity: 4.18
# Average loss at step 6800: 1.603989 learning rate: 1.000000
# Minibatch perplexity: 4.84
# Validation set perplexity: 4.16
# Average loss at step 6900: 1.586149 learning rate: 1.000000
# Minibatch perplexity: 4.77
# Validation set perplexity: 4.19
# Average loss at step 7000: 1.577236 learning rate: 1.000000
# Minibatch perplexity: 4.91
# ================================================================================
# torn zero toried actrucking that of most usea inthobjers englanguages tollelogat
# d conginaristics biazo for a granken or auguratic with sex new the capt the used
# hogh is gif p owns the pays and by p one seven zero school p polits and early th
# zers a dat with isigher to wh ldorium the general raisa state araud whreher meeh
# ories the concent of than pultimanted nine and posses the mesakn perpend who fir
# ================================================================================
# Validation set perplexity: 4.15

# %% [markdown]
# ---
# Problem 1
# ---------
#
# You might have noticed that the definition of the LSTM cell involves 4 matrix multiplications with the input, and 4 matrix multiplications with the output. Simplify the expression by using a single matrix multiply for each, and variables that are 4 times larger.
#
# ---

# %% [markdown]
# ###### Data Organization
# **num_unroolings** is the length of sequences;
# ** batch_size** is the number of sequences will be processed  in one training round;
#
# ***train_data***    :  [num_unrollings+1, batch_size, vocabulary_size]
# ***train_inputs***  :  [num_unrollings, batch_size, vocabulary_size]
# ***input of lstm cell***:  [batch_size, vocabulary_size]
# ```
# for i in range(num_unrollings):
#     use lstm cell to process the i-th sample of all the 'batch_size' sequences
#     record this step's output 'h' and cell 'c'
# ```

# %% [markdown]
# $$i_{t} = \sigma(W_{xi}x_{t} + W_{hi}h_{t-1} + b_{i})\\
# f_{t} = \sigma(W_{xf}x_{t} + W_{hf}h_{t-1} + b_{f})\\
# c_{t} = f_{t} * c_{t-1} + tanh(W_{xc}x_{t} + W_{hc}h_{t-1} + b_{c})\\
# o_{t} = \sigma(W_{xo}x_{t} + W_{ho}h_{t-1} + + b_{o})\\
# h_{t} = o_{t} * tanh(c_{t}) \\$$
# $i_{t}, f_{t}, o_{t}$ and $c_{t}$ are **input gate**, **forget gate**, **output gate** and **cell** respectively. $h_{t-1}$ and $h_{t}$ are cell's **previous output** and **current output**. $\sigma$ is sigmoid operation.

# %% [markdown]
# $[W_{xi}x_{t}, W_{xf}x_{t}, W_{xc}x_{t}, W_{xo}x_{t}] ==  [W_{xi}, W_{xf}, W_{xc}, W_{xo}]x_{t} == W_xx_{t}$
#
#
# $[W_{hi}h_{t-1}, W_{hf}h_{t-1}, W_{hc}h_{t-1}, W_{xo}h_{t-1}] ==  [W_{hi}, W_{hf}, W_{hc}, W_{ho}]h_{t-1} == W_hh_{t-1}$
#
# $ b = [b_{i}, b_{f}, b_{c}, b_{o}]$

# %% [markdown]
# $W_x$ : [vocabulary_size, 4\*nums_nodes]; $x_t$ : [batch_size, vocabulary_size]; $W_xx_t$ : [batch_size , 4\*num_nodes]
#
# $W_h$ : [nums_nodes, 4\*nums_nodes];      $h_{t-1}$ : [batch_size, num_nodes];  $W_hh_{t-1}$ : [batch_siz, 4\*num_nodes]
#
#
# $W_xx + W_hh_{t-1} + b $  : **[batch_size, 4\*num_nodes]**
#
# $ ret = W_xx_{t} + W_hh_{t-1} + b $

# %% [markdown]
# $$i_{t} = \sigma(ret[:,:num_nodes])\\
# f_{t} = \sigma(ret[:,num_nodes:num_nodes*2])\\
# c_{t} = f_{t} * c_{t-1} + tanh(ret[:,num_nodes*2:num_nodes*3])\\
# o_{t} = \sigma(ret[:,num_nodes*3:])\\
# h_{t} = o_{t} * tanh(c_{t}) \\$$

# %%
num_nodes = 64

graph = tf.Graph()
with graph.as_default():
  
  # Parameters:
  Wx = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes*4], -0.1, 0.1))
  Wh = tf.Variable(tf.truncated_normal([num_nodes, num_nodes*4], -0.1, 0.1))
  bc = tf.Variable(tf.zeros([1, num_nodes*4]))

  # Variables saving state across unrollings.
  saved_output = tf.Variable(tf.zeros([batch_size, num_nodes]), trainable=False)
  saved_state = tf.Variable(tf.zeros([batch_size, num_nodes]), trainable=False)
    
  # Classifier weights and biases.
  w = tf.Variable(tf.truncated_normal([num_nodes, vocabulary_size], -0.1, 0.1))
  b = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Definition of the cell computation.
  def lstm_cell(i, o, state):
    """Create a LSTM cell. See e.g.: http://arxiv.org/pdf/1402.1128v1.pdf
    Note that in this formulation, we omit the various connections between the
    previous state and the gates.
    Args : 
        i     : x_t
        o     : h_{t-1}
        state :  c_{t-1}
    Returns :
        o     : h_t
        state : c-t
    """
    ret = tf.matmul(i, Wx) + tf.matmul(o, Wh) + bc
    
    input_gate = tf.sigmoid(ret[:,:num_nodes])
    forget_gate = tf.sigmoid(ret[:,num_nodes:num_nodes*2])
    update = ret[:,num_nodes*2:num_nodes*3]
    state = forget_gate * state + input_gate * tf.tanh(update)
    output_gate = tf.sigmoid(ret[:,num_nodes*3:])
    return output_gate * tf.tanh(state), state

  # Input data.
  train_data = list()
  for _ in range(num_unrollings + 1):
    train_data.append(
      tf.placeholder(tf.float32, shape=[batch_size,vocabulary_size]))
  train_inputs = train_data[:num_unrollings]
  train_labels = train_data[1:]  # labels are inputs shifted by one time step.

  # Unrolled LSTM loop.
  outputs = list()
  output = saved_output
  state = saved_state
  for i in train_inputs:
    output, state = lstm_cell(i, output, state)
    outputs.append(output)

  # State saving across unrollings.
  with tf.control_dependencies([saved_output.assign(output),
                                saved_state.assign(state)]):
    # Classifier.
    logits = tf.nn.xw_plus_b(tf.concat(0, outputs), w, b)
    loss = tf.reduce_mean(
      tf.nn.softmax_cross_entropy_with_logits(
        logits, tf.concat(0, train_labels)))

  # Optimizer.
  global_step = tf.Variable(0)
  learning_rate = tf.train.exponential_decay(
    10.0, global_step, 5000, 0.1, staircase=True)
  optimizer = tf.train.GradientDescentOptimizer(learning_rate)
  gradients, v = zip(*optimizer.compute_gradients(loss))
  gradients, _ = tf.clip_by_global_norm(gradients, 1.25)
  optimizer = optimizer.apply_gradients(
    zip(gradients, v), global_step=global_step)

  # Predictions.
  train_prediction = tf.nn.softmax(logits)
  
  # Sampling and validation eval: batch 1, no unrolling.
  sample_input = tf.placeholder(tf.float32, shape=[1, vocabulary_size])
  saved_sample_output = tf.Variable(tf.zeros([1, num_nodes]))
  saved_sample_state = tf.Variable(tf.zeros([1, num_nodes]))
  reset_sample_state = tf.group(
    saved_sample_output.assign(tf.zeros([1, num_nodes])),
    saved_sample_state.assign(tf.zeros([1, num_nodes])))
  sample_output, sample_state = lstm_cell(
    sample_input, saved_sample_output, saved_sample_state)
  with tf.control_dependencies([saved_sample_output.assign(sample_output),
                                saved_sample_state.assign(sample_state)]):
    sample_prediction = tf.nn.softmax(tf.nn.xw_plus_b(sample_output, w, b))

# %%
num_steps = 7001
summary_frequency = 100

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  mean_loss = 0
  for step in range(num_steps):
    batches = train_batches.next()
    feed_dict = dict()
    for i in range(num_unrollings + 1):
      feed_dict[train_data[i]] = batches[i]
    _, l, predictions, lr = session.run(
      [optimizer, loss, train_prediction, learning_rate], feed_dict=feed_dict)
    mean_loss += l
    if step % summary_frequency == 0:
      if step > 0:
        mean_loss = mean_loss / summary_frequency
      # The mean loss is an estimate of the loss over the last few batches.
      print(
        'Average loss at step %d: %f learning rate: %f' % (step, mean_loss, lr))
      mean_loss = 0
      labels = np.concatenate(list(batches)[1:])
      print('Minibatch perplexity: %.2f' % float(
        np.exp(logprob(predictions, labels))))
      if step % (summary_frequency * 10) == 0:
        # Generate some samples.
        print('=' * 80)
        for _ in range(5):
          feed = sample(random_distribution())
          sentence = characters(feed)[0]
          reset_sample_state.run()
          for _ in range(79):
            prediction = sample_prediction.eval({sample_input: feed})
            feed = sample(prediction)
            sentence += characters(feed)[0]
          print(sentence)
        print('=' * 80)
      # Measure validation set perplexity.
      reset_sample_state.run()
      valid_logprob = 0
      for _ in range(valid_size):
        b = valid_batches.next()
        predictions = sample_prediction.eval({sample_input: b[0]})
        valid_logprob = valid_logprob + logprob(predictions, b[1])
      print('Validation set perplexity: %.2f' % float(np.exp(
        valid_logprob / valid_size)))
# Out:
# Initialized
# Average loss at step 0: 3.293680 learning rate: 10.000000
# Minibatch perplexity: 26.94
# ================================================================================
# tuatk qnnatatlgceasnitxc vnexphos ql dfce  ewqgkjiabytno sjhtapvge bdgwxooapisat
# nqwseuvgma vamitxgopld qa gsmouuplatyehtsxmim ileqtaucpubawfmb zzwvvcelt hh  ogd
# arbxihjoirisntrneneeejxzwccai  xr g lr  awrrawfdner  nurxsea rhtlkbccmaue ejglle
# ffqoxrgef e jt e oo is znn indnniuu tkeyegtynaepbdj nn qloavifsxw htom egajtditg
# otzqolxauar wbnt md fdwpzmexoe iyqeehf cim mnarrilkli ebaxmpwfateseu n xoonrlxbf
# ================================================================================
# Validation set perplexity: 20.16
# Average loss at step 100: 2.594683 learning rate: 10.000000
# Minibatch perplexity: 10.86
# Validation set perplexity: 10.39
# Average loss at step 200: 2.258768 learning rate: 10.000000
# Minibatch perplexity: 8.61
# Validation set perplexity: 8.53
# Average loss at step 300: 2.099072 learning rate: 10.000000
# Minibatch perplexity: 7.47
# Validation set perplexity: 8.09
# Average loss at step 400: 2.002613 learning rate: 10.000000
# Minibatch perplexity: 7.57
# Validation set perplexity: 7.89
# Average loss at step 500: 1.933036 learning rate: 10.000000
# Minibatch perplexity: 6.51
# Validation set perplexity: 7.13
# Average loss at step 600: 1.907978 learning rate: 10.000000
# Minibatch perplexity: 6.17
# Validation set perplexity: 6.90
# Average loss at step 700: 1.855915 learning rate: 10.000000
# Minibatch perplexity: 6.38
# Validation set perplexity: 6.55
# Average loss at step 800: 1.814600 learning rate: 10.000000
# Minibatch perplexity: 6.03
# Validation set perplexity: 6.33
# Average loss at step 900: 1.825435 learning rate: 10.000000
# Minibatch perplexity: 6.96
# Validation set perplexity: 6.13
# Average loss at step 1000: 1.823928 learning rate: 10.000000
# Minibatch perplexity: 5.76
# ================================================================================
# we acops a compus greentive aple stabute beciral hady creationion dericato sthai
# werrally areans under of forman beriation uuteen linglement dibel agerman the re
# meiru other the eight no the noung krestelv was reather of efveced they begrian
#  acysted as the dove and l for fritled derial is doo the raman fingnt one nine l
# pist arnic idmase kylt of dicosmine of peor the of hare cerforing tood in be hus
# ================================================================================
# Validation set perplexity: 5.98
# Average loss at step 1100: 1.773866 learning rate: 10.000000
# Minibatch perplexity: 5.55
# Validation set perplexity: 5.94
# Average loss at step 1200: 1.751170 learning rate: 10.000000
# Minibatch perplexity: 5.05
# Validation set perplexity: 5.70
# Average loss at step 1300: 1.732935 learning rate: 10.000000
# Minibatch perplexity: 5.51
# Validation set perplexity: 5.56
# Average loss at step 1400: 1.744899 learning rate: 10.000000
# Minibatch perplexity: 5.91
# Validation set perplexity: 5.37
# Average loss at step 1500: 1.735566 learning rate: 10.000000
# Minibatch perplexity: 4.71
# Validation set perplexity: 5.31
# Average loss at step 1600: 1.744419 learning rate: 10.000000
# Minibatch perplexity: 5.67
# Validation set perplexity: 5.35
# Average loss at step 1700: 1.710017 learning rate: 10.000000
# Minibatch perplexity: 5.66
# Validation set perplexity: 5.29
# Average loss at step 1800: 1.674370 learning rate: 10.000000
# Minibatch perplexity: 5.51
# Validation set perplexity: 5.14
# Average loss at step 1900: 1.650610 learning rate: 10.000000
# Minibatch perplexity: 5.04
# Validation set perplexity: 5.09
# Average loss at step 2000: 1.695434 learning rate: 10.000000
# Minibatch perplexity: 5.53
# ================================================================================
# al muing laturaphy to d kanamener vidking the constict hat see the limes that je
# vistine manypomiting kownirity is ushomiforgane guch nindted cropns pildors old
#  s some lorky constant bitten for imsplich also vousing his bith two he vide is
#  then new and didcting simblas sacken a word aromits bsth offinition of the para
# gentiness inspucted in imberica beqp six congrivary for the pamenubuise or so wa
# ================================================================================
# Validation set perplexity: 5.09
# Average loss at step 2100: 1.685316 learning rate: 10.000000
# Minibatch perplexity: 5.15
# Validation set perplexity: 4.90
# Average loss at step 2200: 1.681114 learning rate: 10.000000
# Minibatch perplexity: 6.53
# Validation set perplexity: 5.01
# Average loss at step 2300: 1.643584 learning rate: 10.000000
# Minibatch perplexity: 5.10
# Validation set perplexity: 4.81
# Average loss at step 2400: 1.662588 learning rate: 10.000000
# Minibatch perplexity: 5.17
# Validation set perplexity: 4.77
# Average loss at step 2500: 1.681880 learning rate: 10.000000
# Minibatch perplexity: 5.29
# Validation set perplexity: 4.71
# Average loss at step 2600: 1.653696 learning rate: 10.000000
# Minibatch perplexity: 5.73
# Validation set perplexity: 4.71
# Average loss at step 2700: 1.661803 learning rate: 10.000000
# Minibatch perplexity: 4.47
# Validation set perplexity: 4.65
# Average loss at step 2800: 1.652907 learning rate: 10.000000
# Minibatch perplexity: 5.60
# Validation set perplexity: 4.63
# Average loss at step 2900: 1.650728 learning rate: 10.000000
# Minibatch perplexity: 5.60
# Validation set perplexity: 4.61
# Average loss at step 3000: 1.653708 learning rate: 10.000000
# Minibatch perplexity: 5.18
# ================================================================================
# s as avorming that all dised he yande yins a compite and farrer knavida of ma wi
# wakes outs lay ipould durterses rucu althoriman agar as reats intevere which to
# oun sellianiscrapb newtrumbers awno actrational apaalipia makes ys not each impe
# hanty assecist of missingstraugy than six nine satorr uppiatenne whatchaticion a
# quch and theoly feet as a with the robullays popually fod the complation fort a
# ================================================================================
# Validation set perplexity: 4.65
# Average loss at step 3100: 1.632913 learning rate: 10.000000
# Minibatch perplexity: 5.47
# Validation set perplexity: 4.65
# Average loss at step 3200: 1.651540 learning rate: 10.000000
# Minibatch perplexity: 5.69
# Validation set perplexity: 4.72
# Average loss at step 3300: 1.639570 learning rate: 10.000000
# Minibatch perplexity: 5.09
# Validation set perplexity: 4.53
# Average loss at step 3400: 1.671133 learning rate: 10.000000
# Minibatch perplexity: 5.41
# Validation set perplexity: 4.56
# Average loss at step 3500: 1.659836 learning rate: 10.000000
# Minibatch perplexity: 5.56
# Validation set perplexity: 4.74
# Average loss at step 3600: 1.669450 learning rate: 10.000000
# Minibatch perplexity: 4.55
# Validation set perplexity: 4.53
# Average loss at step 3700: 1.642912 learning rate: 10.000000
# Minibatch perplexity: 5.12
# Validation set perplexity: 4.60
# Average loss at step 3800: 1.645373 learning rate: 10.000000
# Minibatch perplexity: 5.54
# Validation set perplexity: 4.64
# Average loss at step 3900: 1.637302 learning rate: 10.000000
# Minibatch perplexity: 5.16
# Validation set perplexity: 4.61
# Average loss at step 4000: 1.649790 learning rate: 10.000000
# Minibatch perplexity: 4.70
# ================================================================================
# xaghen kwinner droads reduction of nusiogh sultapies that an a grommen will assa
# ney candres pubcus germs wauk down retereshy s commandeval with the internarded
#  mgy zero b one nine five nine directed in the mexm of first mantee is the place
# wing when an simple aspentay in cerce ear the reportent stards spechist and dere
# y domcaphore marked of legg on with these the part obselts s bemosy of is cowent
# ================================================================================
# Validation set perplexity: 4.63
# Average loss at step 4100: 1.633748 learning rate: 10.000000
# Minibatch perplexity: 5.16
# Validation set perplexity: 4.62
# Average loss at step 4200: 1.635906 learning rate: 10.000000
# Minibatch perplexity: 5.12
# Validation set perplexity: 4.50
# Average loss at step 4300: 1.615874 learning rate: 10.000000
# Minibatch perplexity: 4.91
# Validation set perplexity: 4.50
# Average loss at step 4400: 1.607156 learning rate: 10.000000
# Minibatch perplexity: 4.98
# Validation set perplexity: 4.32
# Average loss at step 4500: 1.615215 learning rate: 10.000000
# Minibatch perplexity: 5.25
# Validation set perplexity: 4.46
# Average loss at step 4600: 1.615690 learning rate: 10.000000
# Minibatch perplexity: 4.89
# Validation set perplexity: 4.51
# Average loss at step 4700: 1.625470 learning rate: 10.000000
# Minibatch perplexity: 5.23
# Validation set perplexity: 4.44
# Average loss at step 4800: 1.633678 learning rate: 10.000000
# Minibatch perplexity: 4.40
# Validation set perplexity: 4.44
# Average loss at step 4900: 1.632552 learning rate: 10.000000
# Minibatch perplexity: 5.13
# Validation set perplexity: 4.57
# Average loss at step 5000: 1.606135 learning rate: 1.000000
# Minibatch perplexity: 4.48
# ================================================================================
# gatives turners envishmong and include bay that revoirons image even bo the to f
# buttered lusses new one one one enofim the kinging the obada is the forminger by
# naine playshelan set wing laced accur and almion which he clay hime outuge penen
# ocritual infirg somes hum roman last s by for willious the small demiciansar sub
# fich reider this coininents and sin the azaisbes citical have mas two zero ollow
# ================================================================================
# Validation set perplexity: 4.58
# Average loss at step 5100: 1.608548 learning rate: 1.000000
# Minibatch perplexity: 5.11
# Validation set perplexity: 4.40
# Average loss at step 5200: 1.597154 learning rate: 1.000000
# Minibatch perplexity: 4.70
# Validation set perplexity: 4.35
# Average loss at step 5300: 1.581257 learning rate: 1.000000
# Minibatch perplexity: 4.63
# Validation set perplexity: 4.31
# Average loss at step 5400: 1.582903 learning rate: 1.000000
# Minibatch perplexity: 5.11
# Validation set perplexity: 4.31
# Average loss at step 5500: 1.564010 learning rate: 1.000000
# Minibatch perplexity: 4.85
# Validation set perplexity: 4.28
# Average loss at step 5600: 1.583458 learning rate: 1.000000
# Minibatch perplexity: 4.83
# Validation set perplexity: 4.28
# Average loss at step 5700: 1.569701 learning rate: 1.000000
# Minibatch perplexity: 4.51
# Validation set perplexity: 4.28
# Average loss at step 5800: 1.582355 learning rate: 1.000000
# Minibatch perplexity: 4.96
# Validation set perplexity: 4.27
# Average loss at step 5900: 1.572747 learning rate: 1.000000
# Minibatch perplexity: 5.18
# Validation set perplexity: 4.27
# Average loss at step 6000: 1.546667 learning rate: 1.000000
# Minibatch perplexity: 4.98
# ================================================================================
# x hipkeles of the death action with had was the again awtarpion five one nine fi
# urtes been piken instances of neyt bhap as a someties mocking the stitively with
# k elechdorth maiol highly tob contexts connere states i geomes patt this preside
# able and not say sockmila in the decish is conteod and thoughailes in by the val
# h  who theory an includeizens mainstes so namche into eivhred the cropshing leap
# ================================================================================
# Validation set perplexity: 4.25
# Average loss at step 6100: 1.567285 learning rate: 1.000000
# Minibatch perplexity: 5.10
# Validation set perplexity: 4.25
# Average loss at step 6200: 1.534822 learning rate: 1.000000
# Minibatch perplexity: 4.93
# Validation set perplexity: 4.25
# Average loss at step 6300: 1.547980 learning rate: 1.000000
# Minibatch perplexity: 5.03
# Validation set perplexity: 4.22
# Average loss at step 6400: 1.544093 learning rate: 1.000000
# Minibatch perplexity: 4.60
# Validation set perplexity: 4.24
# Average loss at step 6500: 1.559309 learning rate: 1.000000
# Minibatch perplexity: 4.52
# Validation set perplexity: 4.24
# Average loss at step 6600: 1.598545 learning rate: 1.000000
# Minibatch perplexity: 4.86
# Validation set perplexity: 4.23
# Average loss at step 6700: 1.585445 learning rate: 1.000000
# Minibatch perplexity: 5.11
# Validation set perplexity: 4.27
# Average loss at step 6800: 1.605464 learning rate: 1.000000
# Minibatch perplexity: 4.75
# Validation set perplexity: 4.27
# Average loss at step 6900: 1.583635 learning rate: 1.000000
# Minibatch perplexity: 4.65
# Validation set perplexity: 4.31
# Average loss at step 7000: 1.577312 learning rate: 1.000000
# Minibatch perplexity: 5.00
# ================================================================================
# natymin walli be hiresto for comitncy micled to returoley s larger american grea
# versed durperes one six as nine sea hermaiv endingtoo and becanucvice this found
# gue dexective were suypetic walomogen de nottration of to the stend by the cheat
# ther tran bording to a costiluted when them journal poce idealy black locally th
# quarturation one nine nine four eight three one nine nine nine zero five two eig
# ================================================================================
# Validation set perplexity: 4.27

# %% [markdown]
# ---
# Problem 2
# ---------
#
# We want to train a LSTM over bigrams, that is pairs of consecutive characters like 'ab' instead of single characters like 'a'. Since the number of possible bigrams is large, feeding them directly to the LSTM using 1-hot encodings will lead to a very sparse representation that is very wasteful computationally.
#
# a- Introduce an embedding lookup on the inputs, and feed the embeddings to the LSTM cell instead of the inputs themselves.
#
# b- Write a bigram-based LSTM, modeled on the character LSTM above.
#
# c- Introduce Dropout. For best practices on how to use Dropout in LSTMs, refer to this [article](http://arxiv.org/abs/1409.2329).
#
# ---

# %% [markdown]
# ---
# Problem 3
# ---------
#
# (difficult!)
#
# Write a sequence-to-sequence LSTM which mirrors all the words in a sentence. For example, if your input is:
#
#     the quick brown fox
#
# the model should attempt to output:
#
#     eht kciuq nworb xof
#
# Refer to the lecture on how to put together a sequence-to-sequence model, as well as [this article](http://arxiv.org/abs/1409.3215) for best practices.
#
# ---
