# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5236, 3083, 12, 6, 195, 2, 3135, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:12]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'a', 'originated', 'term', 'as', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['a', 'term', 'originated', 'anarchism', 'originated', 'term', 'of', 'as']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.774552
# Nearest to that: sterreich, bows, dahalo, akimbo, healy, tutsi, swaps, harnack,
# Nearest to his: deployment, rudder, marketable, humiliation, dek, drunken, plow, stitched,
# Nearest to has: seize, capacitance, organization, damietta, fini, antinomies, tecumseh, scantily,
# Nearest to system: allosaurus, optionally, greifswald, outfits, ineffectiveness, dialog, apocalypse, floss,
# Nearest to new: mitchell, pfp, paideia, warbird, dendrites, hua, footwear, adjoined,
# Nearest to s: atlanteans, henotheistic, peso, pile, siwa, cowley, five, tonne,
# Nearest to by: signers, agonist, authenticity, dramas, razor, evergreen, allston, criminally,
# Nearest to zero: submerged, allies, innovated, reproductive, separatist, spoilage, annalen, myasthenia,
# Nearest to who: brzezinski, factum, lycaon, often, impulses, cenotaph, hispanics, analyzing,
# Nearest to five: hwv, southwestern, ussachevsky, wwf, encoder, adventures, morphemes, expendable,
# Nearest to most: wally, dolmen, theropods, contingent, clade, evans, nadezhda, nurse,
# Nearest to often: pupils, undefined, enactment, meribbaal, moretti, ploy, who, virility,
# Nearest to this: accord, brace, freire, ire, infused, lettre, strategists, langford,
# Nearest to no: dunfermline, wealthiest, biologically, rivaling, normalize, dicke, sawyer, rudd,
# Nearest to known: dietary, varepsilon, sorbian, penalties, photosynthesis, pcbs, legation, appian,
# Nearest to there: auf, mahjong, outsider, tleilaxu, unalaska, occitan, electorate, flamsteed,
# Average loss at step 2000: 4.358953
# Average loss at step 4000: 3.864726
# Average loss at step 6000: 3.782109
# Average loss at step 8000: 3.691071
# Average loss at step 10000: 3.610870
# Nearest to that: which, bows, this, it, pamplona, johnstone, henrik, medalists,
# Nearest to his: their, its, the, s, her, this, my, tully,
# Nearest to has: was, had, is, have, seize, romanticism, phosphoric, organization,
# Nearest to system: computer, screaming, outfits, allosaurus, resident, bamberger, apocalypse, protectorates,
# Nearest to new: nice, mitchell, hua, ambitious, footwear, publicity, pfp, dendrites,
# Nearest to s: his, tsiolkovsky, and, william, fulvia, gurus, dandies, emile,
# Nearest to by: with, was, on, imam, cours, as, in, express,
# Nearest to zero: seven, nine, five, six, eight, three, four, two,
# Nearest to who: often, he, also, transitional, hell, they, nuevo, lar,
# Nearest to five: eight, six, three, seven, four, nine, zero, two,
# Nearest to most: wally, batista, some, more, mather, johns, ingrained, contingent,
# Nearest to often: who, longsword, platforms, streptococcus, they, uppermost, ploy, also,
# Nearest to this: it, the, which, a, that, ire, his, overpopulation,
# Nearest to no: havoc, abodes, unacceptable, it, otherwise, sawyer, rivaling, wealthiest,
# Nearest to known: dietary, penalties, legation, randal, a, dominus, famous, zulu,
# Nearest to there: it, they, he, medalists, not, unalaska, mahjong, tleilaxu,
# Average loss at step 12000: 3.606200
# Average loss at step 14000: 3.572330
# Average loss at step 16000: 3.407541
# Average loss at step 18000: 3.458829
# Average loss at step 20000: 3.539585
# Nearest to that: which, but, actinidia, bows, closely, surgically, this, hit,
# Nearest to his: their, its, her, my, the, tully, kits, solidify,
# Nearest to has: had, was, is, have, having, seize, antiprotons, fisch,
# Nearest to system: computer, screaming, kind, swelled, resident, associated, apocalypse, allosaurus,
# Nearest to new: nice, hua, second, mitchell, latin, ambitious, cryptozoology, publicity,
# Nearest to s: barking, tsiolkovsky, william, maryam, dandies, parametric, receipts, prelog,
# Nearest to by: were, on, with, amazing, in, against, be, during,
# Nearest to zero: five, six, eight, three, four, seven, nine, two,
# Nearest to who: he, often, which, she, they, also, transitional, resistors,
# Nearest to five: three, eight, seven, six, four, zero, two, nine,
# Nearest to most: more, some, many, batista, johns, ishaq, wally, ingrained,
# Nearest to often: who, also, sometimes, streptococcus, widely, platforms, usually, which,
# Nearest to this: it, which, the, a, upright, memorial, groomed, redirection,
# Nearest to no: unacceptable, demigods, chewed, it, namespaces, navarrese, wealthiest, wildstorm,
# Nearest to known: penalties, dietary, legation, such, famous, randal, far, used,
# Nearest to there: they, it, he, which, unalaska, untenable, cctld, medalists,
# Average loss at step 22000: 3.498406
# Average loss at step 24000: 3.489323
# Average loss at step 26000: 3.483922
# Average loss at step 28000: 3.481359
# Average loss at step 30000: 3.497180
# Nearest to that: which, this, dekalb, what, however, bows, but, actinidia,
# Nearest to his: their, her, its, my, the, s, tully, combatants,
# Nearest to has: had, have, was, is, having, phosphoric, christianization, veterinary,
# Nearest to system: computer, swelled, systems, allosaurus, defun, riley, unpredictability, sylvia,
# Nearest to new: second, nice, taino, mh, latin, cryptozoology, accumulations, ambitious,
# Nearest to s: whose, his, barking, parametric, william, prelog, yam, guarded,
# Nearest to by: under, flutie, in, from, was, him, been, filthy,
# Nearest to zero: five, four, eight, seven, six, three, nine, two,
# Nearest to who: he, often, she, which, they, also, actually, there,
# Nearest to five: four, six, seven, eight, three, zero, two, nine,
# Nearest to most: more, some, many, batista, wally, contingent, ingrained, malibu,
# Nearest to often: sometimes, usually, also, who, widely, frequently, commonly, streptococcus,
# Nearest to this: which, it, that, any, barbecue, every, estimates, burst,
# Nearest to no: touted, a, namespaces, demigods, unacceptable, antes, wildstorm, chewed,
# Nearest to known: used, famous, such, penalties, defined, well, randal, insulator,
# Nearest to there: they, it, he, often, now, who, untenable, usually,
# Average loss at step 32000: 3.501533
# Average loss at step 34000: 3.492608
# Average loss at step 36000: 3.451609
# Average loss at step 38000: 3.306582
# Average loss at step 40000: 3.428472
# Nearest to that: which, this, however, what, but, dekalb, urim, where,
# Nearest to his: their, her, its, my, your, tully, the, our,
# Nearest to has: had, have, was, is, having, phosphoric, antiprotons, motocross,
# Nearest to system: systems, riley, computer, etruscan, sylvia, possible, swelled, allosaurus,
# Nearest to new: nice, second, cryptozoology, illuminatus, visual, toho, copyleft, latin,
# Nearest to s: his, had, whose, alfa, barbarism, confesses, assented, sextus,
# Nearest to by: with, widening, as, whomever, farc, radiotelephone, be, through,
# Nearest to zero: five, seven, eight, six, nine, two, three, four,
# Nearest to who: often, he, which, also, she, they, actually, auditioning,
# Nearest to five: seven, six, four, three, eight, zero, two, nine,
# Nearest to most: more, some, many, among, contingent, breathy, mather, hickman,
# Nearest to often: sometimes, usually, also, widely, who, frequently, commonly, generally,
# Nearest to this: which, that, it, juries, any, the, another, groupoid,
# Nearest to no: touted, any, navarrese, chewed, still, it, antes, motionless,
# Nearest to known: used, such, famous, defined, well, regarded, figueres, featured,
# Nearest to there: it, they, usually, he, now, often, also, which,
# Average loss at step 42000: 3.430781
# Average loss at step 44000: 3.449210
# Average loss at step 46000: 3.451647
# Average loss at step 48000: 3.350890
# Average loss at step 50000: 3.383346
# Nearest to that: which, however, where, actinidia, dekalb, surgically, what, this,
# Nearest to his: their, her, its, my, your, tully, our, whose,
# Nearest to has: had, have, was, is, since, verdict, having, does,
# Nearest to system: systems, computer, riley, allosaurus, etruscan, swelled, mali, unpredictability,
# Nearest to new: nice, illuminatus, visual, second, toho, copyleft, cryptozoology, third,
# Nearest to s: whose, while, his, fractured, pandemic, melds, but, choir,
# Nearest to by: through, fingerboard, was, with, during, defied, flutie, against,
# Nearest to zero: seven, four, six, three, eight, five, nine, two,
# Nearest to who: he, she, which, often, they, and, sworn, now,
# Nearest to five: four, six, seven, three, eight, two, zero, nine,
# Nearest to most: more, some, many, among, mather, transform, particularly, use,
# Nearest to often: sometimes, usually, generally, frequently, now, commonly, widely, typically,
# Nearest to this: which, it, the, he, that, groupoid, juries, antidepressant,
# Nearest to no: any, namespaces, touted, demigods, ejection, every, a, little,
# Nearest to known: used, such, famous, defined, regarded, well, figueres, featured,
# Nearest to there: they, it, he, now, usually, often, these, cronje,
# Average loss at step 52000: 3.439160
# Average loss at step 54000: 3.424168
# Average loss at step 56000: 3.436441
# Average loss at step 58000: 3.396811
# Average loss at step 60000: 3.393224
# Nearest to that: which, this, what, however, where, actinidia, sticking, dekalb,
# Nearest to his: her, their, its, my, tully, your, our, combatants,
# Nearest to has: had, have, was, is, having, unmolested, veterinary, gluten,
# Nearest to system: systems, computer, riley, service, etruscan, segregation, swelled, allosaurus,
# Nearest to new: cryptozoology, nice, copyleft, menander, phipps, twelfth, cem, visual,
# Nearest to s: whose, my, transnational, yoshitaka, shari, psilocybin, bocks, purportedly,
# Nearest to by: with, through, without, defied, galway, unmolested, from, amazing,
# Nearest to zero: five, eight, four, seven, six, nine, three, two,
# Nearest to who: which, he, she, often, now, sworn, actually, still,
# Nearest to five: six, four, three, eight, seven, nine, zero, two,
# Nearest to most: more, some, many, particularly, use, among, less, memex,
# Nearest to often: sometimes, usually, now, frequently, commonly, generally, typically, widely,
# Nearest to this: it, which, that, forbid, some, there, the, redirection,
# Nearest to no: any, namespaces, touted, little, demigods, motionless, til, cunning,
# Nearest to known: used, such, famous, defined, regarded, well, ringers, figueres,
# Nearest to there: it, they, now, he, usually, often, she, this,
# Average loss at step 62000: 3.241360
# Average loss at step 64000: 3.251753
# Average loss at step 66000: 3.404111
# Average loss at step 68000: 3.396232
# Average loss at step 70000: 3.356258
# Nearest to that: which, however, what, this, usually, where, actinidia, still,
# Nearest to his: her, their, its, my, tully, your, the, our,
# Nearest to has: had, have, is, was, since, having, phosphoric, holds,
# Nearest to system: systems, segregation, riley, contraception, etruscan, sustainable, service, nem,
# Nearest to new: cryptozoology, nice, copyleft, phipps, menander, professional, neuralgia, bringing,
# Nearest to s: whose, emile, isbn, msn, william, alfa, naomi, my,
# Nearest to by: through, galway, without, using, aung, was, be, amazing,
# Nearest to zero: five, six, four, eight, seven, three, nine, two,
# Nearest to who: actually, she, sworn, which, they, often, he, now,
# Nearest to five: four, six, three, eight, seven, zero, nine, two,
# Nearest to most: more, some, many, less, particularly, use, among, contingent,
# Nearest to often: sometimes, usually, frequently, generally, commonly, now, widely, typically,
# Nearest to this: which, it, the, that, some, inked, alston, there,
# Nearest to no: any, namespaces, little, touted, antes, onwards, til, nsh,
# Nearest to known: used, such, defined, regarded, famous, well, responsible, featured,
# Nearest to there: they, it, he, usually, we, now, still, sometimes,
# Average loss at step 72000: 3.370727
# Average loss at step 74000: 3.349908
# Average loss at step 76000: 3.320924
# Average loss at step 78000: 3.351313
# Average loss at step 80000: 3.375597
# Nearest to that: which, however, actinidia, where, indestructible, alberti, claimants, sticking,
# Nearest to his: her, their, my, its, our, your, tully, niall,
# Nearest to has: had, have, is, was, since, although, holds, having,
# Nearest to system: systems, segregation, scheme, riley, data, service, pl, sustainable,
# Nearest to new: nice, phipps, hellenistic, cryptozoology, illuminatus, chapel, transfers, plosive,
# Nearest to s: isbn, swnt, vestigial, tristram, my, demonstrators, baked, william,
# Nearest to by: through, when, filthy, whomever, widening, was, aung, guangzhou,
# Nearest to zero: seven, five, six, eight, three, four, nine, two,
# Nearest to who: she, actually, sworn, often, now, he, usually, which,
# Nearest to five: six, four, seven, eight, three, nine, two, zero,
# Nearest to most: more, many, some, less, particularly, contingent, memex, hickman,
# Nearest to often: sometimes, usually, frequently, generally, commonly, typically, now, still,
# Nearest to this: which, it, the, groupoid, ethereal, another, forbid, resizing,
# Nearest to no: little, any, pld, touted, onwards, chewed, namespaces, jadwiga,
# Nearest to known: used, regarded, defined, such, famous, responsible, recognized, seen,
# Nearest to there: it, they, he, usually, now, still, she, often,
# Average loss at step 82000: 3.407156
# Average loss at step 84000: 3.412180
# Average loss at step 86000: 3.386614
# Average loss at step 88000: 3.349580
# Average loss at step 90000: 3.363705
# Nearest to that: however, which, what, where, but, sticking, surgically, opold,
# Nearest to his: her, their, its, my, our, your, tully, the,
# Nearest to has: had, have, is, was, having, although, requires, veterinary,
# Nearest to system: systems, data, riley, caller, segregation, map, scheme, cable,
# Nearest to new: apostrophe, hellenistic, thirty, nice, illuminatus, parables, ballista, manzikert,
# Nearest to s: whose, isbn, lymphocyte, pandemic, his, my, her, sextus,
# Nearest to by: through, without, using, with, from, filthy, amx, defied,
# Nearest to zero: five, eight, six, seven, four, nine, three, two,
# Nearest to who: often, he, she, sworn, which, actually, now, also,
# Nearest to five: eight, seven, six, four, three, nine, two, zero,
# Nearest to most: more, less, some, many, particularly, hickman, use, especially,
# Nearest to often: sometimes, usually, frequently, generally, commonly, now, typically, widely,
# Nearest to this: it, which, juries, some, the, groupoid, any, another,
# Nearest to no: little, any, namespaces, touted, pld, foraging, navarrese, til,
# Nearest to known: used, regarded, such, famous, defined, described, called, responsible,
# Nearest to there: they, it, he, still, now, she, we, usually,
# Average loss at step 92000: 3.397878
# Average loss at step 94000: 3.255121
# Average loss at step 96000: 3.357785
# Average loss at step 98000: 3.244193
# Average loss at step 100000: 3.357454
# Nearest to that: which, however, what, where, actinidia, swaps, this, but,
# Nearest to his: her, their, my, your, our, its, the, s,
# Nearest to has: had, have, is, was, since, having, holds, requires,
# Nearest to system: systems, model, services, scheme, method, cable, compact, map,
# Nearest to new: cryptozoology, illuminatus, transfers, single, apostrophe, different, spate, hellenistic,
# Nearest to s: whose, my, his, isbn, your, psilocybin, huygens, naomi,
# Nearest to by: filthy, through, aung, under, when, caso, without, escrow,
# Nearest to zero: five, seven, four, eight, six, nine, three, million,
# Nearest to who: actually, she, he, still, also, now, sworn, often,
# Nearest to five: four, six, seven, eight, three, two, nine, zero,
# Nearest to most: more, less, particularly, especially, contingent, many, hickman, some,
# Nearest to often: sometimes, usually, generally, frequently, commonly, typically, now, widely,
# Nearest to this: which, it, another, he, some, the, juries, redirection,
# Nearest to no: little, any, namespaces, til, pld, touted, foraging, mitford,
# Nearest to known: such, used, regarded, defined, famous, responsible, available, described,
# Nearest to there: they, it, he, now, still, usually, we, often,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %% [markdown]
# In a skip-gram model, the model use [target word, context word] as [train data, train label].
# In a CBOW model, the model use [sum of context words, target word] as [train data, train label]

# %%
type(reverse_dictionary)
# Out:
# dict

# %%
data_index = 0

def generate_batch(batch_size, window_size):
  global data_index
  span = 2 * window_size + 1 # [ words in history, target, words in future]
  batch = np.ndarray(shape=(batch_size, span - 1), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size ):
    target = window_size  # target label at the center of the buffer
    for j in range(window_size):
        batch[i, j] = buffer[j]
    for j in range(window_size):
        batch[i, j+window_size] = buffer[j+window_size+1]
    labels[i, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:12]])

for window_size in [2,4]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, window_size=window_size)
    print('\nwith window_size = %d :' % (window_size))
    for i,bi in enumerate(batch):
        print('batch :', [reverse_dictionary[i] for i in bi])
        print('label :', [reverse_dictionary[labels[i,0]]])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working']
#
# with window_size = 2 :
# ['anarchism', 'originated', 'a', 'term']
#  ['as']
# ['originated', 'as', 'term', 'of']
#  ['a']
# ['as', 'a', 'of', 'abuse']
#  ['term']
# ['a', 'term', 'abuse', 'first']
#  ['of']
# ['term', 'of', 'first', 'used']
#  ['abuse']
# ['of', 'abuse', 'used', 'against']
#  ['first']
# ['abuse', 'first', 'against', 'early']
#  ['used']
# ['first', 'used', 'early', 'working']
#  ['against']
#
# with window_size = 4 :
# ['anarchism', 'originated', 'as', 'a', 'of', 'abuse', 'first', 'used']
#  ['term']
# ['originated', 'as', 'a', 'term', 'abuse', 'first', 'used', 'against']
#  ['of']
# ['as', 'a', 'term', 'of', 'first', 'used', 'against', 'early']
#  ['abuse']
# ['a', 'term', 'of', 'abuse', 'used', 'against', 'early', 'working']
#  ['first']
# ['term', 'of', 'abuse', 'first', 'against', 'early', 'working', 'class']
#  ['used']
# ['of', 'abuse', 'first', 'used', 'early', 'working', 'class', 'radicals']
#  ['against']
# ['abuse', 'first', 'used', 'against', 'working', 'class', 'radicals', 'including']
#  ['early']
# ['first', 'used', 'against', 'early', 'class', 'radicals', 'including', 'the']
#  ['working']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
window_size = 2 # How many words to consider left and right.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size, window_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  
  # sum all the context word vectors
  # embed shape : [batch_size, window_size, embedding_size]
  # embed_sum shape : [batch_size, embedding_size]
  embed_sum = tf.reduce_sum(embed, 1)
  print(embed.get_shape(),embed_sum.get_shape())  
    
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed_sum,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))
# Out:
# (128, 2, 128) (128, 128)

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 6.733834
# Nearest to three: booted, physicians, peacefully, cyclopedia, tat, moralistic, kline, capability,
# Nearest to he: sk, cleves, sawdust, skill, humid, extolling, vba, risings,
# Nearest to UNK: mediums, cursus, encephalitis, obstetrics, merlot, sideband, friday, prompt,
# Nearest to new: murder, whites, earlier, speleology, remake, cathodes, pride, tobias,
# Nearest to more: mix, emissary, sorts, seyss, ceremony, ordained, junkers, supplying,
# Nearest to an: admonished, subsisting, psalms, frantz, alphabetically, scuba, cuzco, innumerable,
# Nearest to these: bobo, telegraph, fifa, satirizes, poids, medieval, cretans, shadowed,
# Nearest to most: memes, chesterfield, cheerleading, blanket, roswell, protons, kantian, rates,
# Nearest to no: chiefs, accompanied, tagore, tradesmen, illustrating, predicted, pompeii, sgh,
# Nearest to to: litigants, dysfunction, bruises, intermediaries, artistry, characterizes, ayres, pulse,
# Nearest to in: microtubules, rosewood, panther, autodesk, honduras, mcqueen, orville, rukh,
# Nearest to b: organisation, polypeptide, possum, extrusive, someday, votes, expressly, brandt,
# Nearest to are: vienna, goya, topaz, hayden, attenborough, reappear, mobster, neodymium,
# Nearest to after: escrow, accumulations, gallop, lya, conserve, feathered, whatever, ulyanov,
# Nearest to s: aquileia, reductionism, projectors, handicap, padded, notional, amphitheatre, eurovision,
# Nearest to on: leonard, pimlico, inhospitable, foote, resumption, camelids, thaw, ventris,
# Average loss at step 2000: 4.097647
# Average loss at step 4000: 3.561350
# Average loss at step 6000: 3.387990
# Average loss at step 8000: 3.240220
# Average loss at step 10000: 3.177063
# Nearest to three: six, four, two, eight, five, seven, nine, zero,
# Nearest to he: it, she, they, who, functionalist, plunging, turboprop, busting,
# Nearest to UNK: apostate, importer, wheatstone, larvae, kazakstan, randal, battleship, esc,
# Nearest to new: earlier, speleology, predominates, generalisation, murder, majority, morphological, whites,
# Nearest to more: less, most, topsy, brigadier, jaffna, clinic, azali, cruisers,
# Nearest to an: scuba, procol, distantly, webb, ying, smite, abbess, decennial,
# Nearest to these: many, medieval, all, some, thorne, smiles, mcclellan, rameau,
# Nearest to most: more, blanket, some, aesthetics, arbroath, puberty, chainsaw, rates,
# Nearest to no: a, any, tradesmen, hostile, purr, illustrating, denny, facilitates,
# Nearest to to: not, could, bruises, can, sacu, will, colophon, albornoz,
# Nearest to in: at, on, between, during, slide, subsection, of, resentment,
# Nearest to b: d, gatling, intervenes, apocr, deport, irv, extrusive, saturation,
# Nearest to are: were, is, have, was, be, hayden, fanzines, firewalls,
# Nearest to after: before, obliquely, gallop, snake, with, from, aphelion, gulfs,
# Nearest to s: bus, gatekeeper, minutes, roadie, headroom, participant, honours, southside,
# Nearest to on: in, apologetics, at, upon, foote, twa, gothenburg, strangely,
# Average loss at step 12000: 3.193668
# Average loss at step 14000: 3.152449
# Average loss at step 16000: 3.179815
# Average loss at step 18000: 3.126766
# Average loss at step 20000: 2.987165
# Nearest to three: four, seven, five, six, two, eight, nine, zero,
# Nearest to he: she, it, they, who, eventually, there, never, turboprop,
# Nearest to UNK: convent, com, merseburg, aml, slap, vivo, c, menstrual,
# Nearest to new: earlier, contralto, bilabial, majority, speleology, jurisdiction, chokes, third,
# Nearest to more: less, most, very, barristers, philanthropic, rather, jaffna, recordings,
# Nearest to an: procol, overly, distantly, abbess, stoiber, celestial, ying, frantz,
# Nearest to these: many, some, such, which, several, various, they, those,
# Nearest to most: more, some, puberty, battery, many, miko, fairness, trades,
# Nearest to no: any, denny, tradesmen, facilitates, a, hostile, titanium, doesburg,
# Nearest to to: can, microtonal, colophon, must, albornoz, will, magistracy, not,
# Nearest to in: within, at, during, of, reset, on, and, chronometers,
# Nearest to b: d, renovate, extrusive, gatling, phoneme, laps, apocr, preventing,
# Nearest to are: were, is, have, astrometric, be, was, chrono, include,
# Nearest to after: before, during, from, when, herzog, snake, feeders, durban,
# Nearest to s: my, bus, his, southside, ditto, artaxerxes, gatekeeper, scent,
# Nearest to on: upon, at, victor, strangely, about, couch, swiss, against,
# Average loss at step 22000: 3.070984
# Average loss at step 24000: 3.035896
# Average loss at step 26000: 3.002837
# Average loss at step 28000: 3.032739
# Average loss at step 30000: 3.002300
# Nearest to three: five, six, four, two, seven, eight, nine, one,
# Nearest to he: she, it, they, who, there, eventually, we, vcd,
# Nearest to UNK: rajendra, cocaine, venizelos, lancashire, von, brocklin, brancusi, burckhardt,
# Nearest to new: majority, earlier, spokesman, jurisdiction, chokes, contralto, murder, third,
# Nearest to more: less, most, very, barristers, jaffna, extremely, rather, topsy,
# Nearest to an: timorese, ying, distantly, overly, the, decennial, caliphs, bamboo,
# Nearest to these: many, such, some, several, various, both, those, all,
# Nearest to most: some, more, many, yugoslavia, miko, trades, innovative, particularly,
# Nearest to no: any, denny, facilitates, rampage, tradesmen, little, suzy, grieving,
# Nearest to to: would, can, could, will, may, albornoz, might, must,
# Nearest to in: within, during, on, since, boswell, of, from, until,
# Nearest to b: d, renovate, f, loki, preventing, obstructions, rosen, shoreline,
# Nearest to are: were, have, is, astrometric, include, koine, destroyers, including,
# Nearest to after: before, when, during, while, without, as, from, miniature,
# Nearest to s: whose, isbn, rita, accomplishment, began, manipulative, my, artaxerxes,
# Nearest to on: upon, in, apologetics, about, under, strangely, at, swiss,
# Average loss at step 32000: 2.826608
# Average loss at step 34000: 2.949370
# Average loss at step 36000: 2.945469
# Average loss at step 38000: 2.942005
# Average loss at step 40000: 2.932491
# Nearest to three: four, five, six, seven, eight, two, nine, zero,
# Nearest to he: she, it, they, there, who, we, eventually, pflp,
# Nearest to UNK: targaryen, jones, neurotransmitters, passionately, handler, rutger, outtakes, hagia,
# Nearest to new: chokes, earlier, notches, contralto, majority, normandy, meritocracy, jurisdiction,
# Nearest to more: less, most, very, highly, larger, extremely, fewer, topsy,
# Nearest to an: overly, barr, timorese, abbess, intentionally, meaningless, cnidaria, decennial,
# Nearest to these: those, such, several, many, various, some, both, their,
# Nearest to most: more, some, less, many, particularly, miko, breaker, trades,
# Nearest to no: little, denny, avery, any, horizontal, properly, doesburg, facilitates,
# Nearest to to: will, callahan, towards, would, can, shall, into, should,
# Nearest to in: during, within, throughout, until, with, among, since, mani,
# Nearest to b: renovate, d, shoreline, bush, string, bundeswehr, rosen, f,
# Nearest to are: were, have, is, include, although, those, including, koine,
# Nearest to after: before, during, when, from, as, while, miniature, without,
# Nearest to s: isbn, whomever, stalk, whose, scent, flagship, hen, reins,
# Nearest to on: upon, swiss, foote, under, marching, through, mueller, renegades,
# Average loss at step 42000: 2.949136
# Average loss at step 44000: 2.958589
# Average loss at step 46000: 2.910469
# Average loss at step 48000: 2.868583
# Average loss at step 50000: 2.844981
# Nearest to three: two, seven, six, four, five, eight, zero, nine,
# Nearest to he: she, it, they, there, who, eventually, later, we,
# Nearest to UNK: hamilton, incited, der, br, jones, trap, shafi, eater,
# Nearest to new: old, chokes, earlier, contralto, different, normandy, spokesman, particular,
# Nearest to more: less, most, very, rather, topsy, better, longer, larger,
# Nearest to an: abbess, overly, intentionally, dura, bamboo, ying, distantly, timorese,
# Nearest to these: several, various, many, some, those, multiple, such, which,
# Nearest to most: more, some, less, many, trades, all, especially, asterix,
# Nearest to no: little, any, only, someone, rampage, altair, grieving, facilitates,
# Nearest to to: albornoz, will, chronometers, towards, microtonal, callahan, monetarist, magistracy,
# Nearest to in: during, within, at, on, from, boswell, walkway, until,
# Nearest to b: d, bush, renovate, c, interconnected, cics, strathclyde, derrida,
# Nearest to are: were, have, is, include, be, destroyers, contain, while,
# Nearest to after: before, when, during, without, while, despite, though, feeders,
# Nearest to s: gatekeeper, whose, isbn, manipulative, my, monarchic, falwell, ditto,
# Nearest to on: upon, in, under, strangely, during, rebus, at, elaborately,
# Average loss at step 52000: 2.886883
# Average loss at step 54000: 2.860559
# Average loss at step 56000: 2.860725
# Average loss at step 58000: 2.752673
# Average loss at step 60000: 2.826476
# Nearest to three: four, six, five, two, seven, eight, nine, zero,
# Nearest to he: she, it, they, eventually, there, who, perfecti, constructivist,
# Nearest to UNK: glucose, burckhardt, guzm, reptile, woodrow, m, o, bryozoa,
# Nearest to new: different, earlier, unadorned, old, specific, ops, hasidic, particular,
# Nearest to more: less, most, very, rather, topsy, highly, quite, larger,
# Nearest to an: abbess, distantly, barr, intentionally, decennial, bamboo, alleging, pundits,
# Nearest to these: several, those, various, many, some, such, which, instead,
# Nearest to most: more, less, especially, use, some, particularly, schola, many,
# Nearest to no: little, another, any, rampage, altair, otherwise, facilitates, some,
# Nearest to to: will, would, callahan, might, could, must, albornoz, microtonal,
# Nearest to in: within, during, at, among, throughout, under, on, of,
# Nearest to b: d, c, renovate, h, g, laps, frac, x,
# Nearest to are: were, is, have, include, contain, astrometric, although, malinowski,
# Nearest to after: before, during, when, despite, without, within, while, if,
# Nearest to s: whose, isbn, alembert, his, whomever, your, stalk, perro,
# Nearest to on: upon, within, under, through, in, at, during, strangely,
# Average loss at step 62000: 2.831439
# Average loss at step 64000: 2.771948
# Average loss at step 66000: 2.761146
# Average loss at step 68000: 2.714689
# Average loss at step 70000: 2.780402
# Nearest to three: seven, five, six, four, eight, two, nine, zero,
# Nearest to he: she, it, they, who, eventually, there, we, never,
# Nearest to UNK: kush, intestinal, sept, o, cmmi, br, huckleberry, ois,
# Nearest to new: different, particular, mamre, hasidic, third, unadorned, specific, synthetic,
# Nearest to more: less, most, very, quite, rather, topsy, highly, greater,
# Nearest to an: another, overly, distantly, intentionally, abbess, timorese, barr, whorf,
# Nearest to these: those, some, several, various, many, instead, which, both,
# Nearest to most: more, less, particularly, especially, many, some, asterix, yugoslavia,
# Nearest to no: another, any, grieving, little, altair, someone, retrieve, rampage,
# Nearest to to: will, albornoz, towards, would, callahan, must, colophon, can,
# Nearest to in: during, within, throughout, of, at, on, under, since,
# Nearest to b: d, krantz, benevento, fukuoka, interconnected, cae, appleton, sliding,
# Nearest to are: were, include, have, is, contain, remain, legionary, those,
# Nearest to after: before, during, when, despite, without, if, while, from,
# Nearest to s: whose, isbn, whomever, his, alembert, ditto, yemen, perro,
# Nearest to on: upon, within, under, around, in, through, near, rebus,
# Average loss at step 72000: 2.793667
# Average loss at step 74000: 2.642790
# Average loss at step 76000: 2.800882
# Average loss at step 78000: 2.824714
# Average loss at step 80000: 2.779150
# Nearest to three: five, six, four, two, eight, seven, zero, one,
# Nearest to he: she, it, they, who, there, constructivist, we, eventually,
# Nearest to UNK: r, br, ne, p, effendi, mexicana, dorothea, johnson,
# Nearest to new: different, specific, evils, synthetic, speleology, particular, pride, mamre,
# Nearest to more: less, very, most, quite, rather, highly, fewer, better,
# Nearest to an: intentionally, abbess, distantly, another, overly, barr, caliphs, ying,
# Nearest to these: those, some, several, many, such, which, various, their,
# Nearest to most: many, more, less, use, some, all, especially, because,
# Nearest to no: little, any, another, someone, spokane, criminality, grieving, decorated,
# Nearest to to: callahan, should, will, towards, might, albornoz, can, would,
# Nearest to in: during, within, at, throughout, under, near, on, of,
# Nearest to b: d, c, r, h, krantz, n, shoreline, gorges,
# Nearest to are: were, is, have, include, contain, usually, although, remain,
# Nearest to after: before, during, when, despite, without, while, since, if,
# Nearest to s: whose, isbn, southside, whomever, enveloping, alembert, irda, actium,
# Nearest to on: upon, in, around, during, through, strangely, spawn, corporatism,
# Average loss at step 82000: 2.665735
# Average loss at step 84000: 2.771802
# Average loss at step 86000: 2.731464
# Average loss at step 88000: 2.748988
# Average loss at step 90000: 2.734289
# Nearest to three: four, five, two, six, eight, seven, zero, nine,
# Nearest to he: she, it, they, who, there, we, i, eventually,
# Nearest to UNK: arresting, tutoring, br, lancashire, johnson, facto, lee, contravening,
# Nearest to new: different, highways, painstaking, evils, old, nmi, specific, pride,
# Nearest to more: less, very, most, quite, rather, fewer, highly, greater,
# Nearest to an: intentionally, overly, distantly, abbess, another, dinah, lekhanya, timorese,
# Nearest to these: those, such, some, several, multiple, various, many, examples,
# Nearest to most: many, more, especially, some, less, all, particularly, yugoslavia,
# Nearest to no: little, any, another, become, decorated, spokane, otherwise, suzy,
# Nearest to to: must, might, would, callahan, will, could, should, towards,
# Nearest to in: within, during, on, at, throughout, including, near, among,
# Nearest to b: d, c, shoreline, r, reciprocate, krantz, e, renovate,
# Nearest to are: were, is, include, have, contain, including, malinowski, oecs,
# Nearest to after: before, during, despite, when, without, since, if, within,
# Nearest to s: whose, isbn, peninsulas, whomever, his, fx, headroom, and,
# Nearest to on: upon, in, through, strangely, renegades, at, around, within,
# Average loss at step 92000: 2.675844
# Average loss at step 94000: 2.723831
# Average loss at step 96000: 2.701468
# Average loss at step 98000: 2.362495
# Average loss at step 100000: 2.393522
# Nearest to three: four, five, six, seven, eight, two, nine, zero,
# Nearest to he: she, they, it, there, we, who, plunging, even,
# Nearest to UNK: br, ois, osaka, morgan, shafi, en, markkaa, petrochemical,
# Nearest to new: different, old, evils, nmi, highways, chokes, painstaking, mamre,
# Nearest to more: less, most, fewer, very, quite, rather, better, patrimony,
# Nearest to an: intentionally, abbess, overly, ying, distantly, owen, timorese, caliphs,
# Nearest to these: those, such, several, multiple, some, examples, various, certain,
# Nearest to most: more, less, especially, some, many, particularly, yugoslavia, extremely,
# Nearest to no: little, any, nothing, spokane, ordovician, suzy, someone, kath,
# Nearest to to: should, might, would, will, shall, albornoz, callahan, can,
# Nearest to in: during, at, near, within, throughout, among, of, on,
# Nearest to b: d, krantz, derrida, cricketer, saturation, christine, tfl, sweat,
# Nearest to are: were, include, is, contain, have, remain, those, hayden,
# Nearest to after: before, during, despite, when, without, for, if, following,
# Nearest to s: whose, isbn, american, stalk, ditto, jane, my, ennis,
# Nearest to on: upon, around, at, strangely, through, disbandment, jain, in,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
